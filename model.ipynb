# %%
documents = [
    "I love this movie",
    "This movie is amazing",
    "I really enjoyed the film",
    "I hate this movie",
    "This movie is terrible",
    "I did not enjoy the film"
]

labels = [
    "positive",
    "positive",
    "positive",
    "negative",
    "negative",
    "negative"
]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    documents,
    labels,
    test_size=0.2,
    random_state=4
)

# %%
X_train

# %%
X_test

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

X_train_bow = vectorizer.fit_transform(X_train)
X_test_bow = vectorizer.transform(X_test)

vectorizer.get_feature_names_out()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tidf = vectorizer.transform(X_test)

vectorizer.get_feature_names_out()

# %%
X_train_bow.toarray()

# %%
import pandas as pd

bow = pd.DataFrame(X_train_bow.toarray(),
                   columns = vectorizer.get_feature_names_out())

bow['class'] = y_train

bow

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()

model.fit(X_train_bow, y_train)

# %%
predictions = model.predict(X_test_bow)

print(y_test)
print(predictions)

# %%
model.classes_

# %%
model.class_log_prior_

# %%
probability = pd.DataFrame(
    model.feature_log_prob_,
    columns=vectorizer.get_feature_names_out(),
    index=model.classes_
)
probability

# %%
new_review = ["I hate this movie"]

new_bow = vectorizer.transform(new_review)

print(model.predict(new_bow))
print(model.predict_log_proba(new_bow))
print(model.classes_)

# %%
documents = [
    "camera photography lens photo",
    "photography camera lens portrait",
    "camera photo lens digital photography",
    "football player goal match",
    "football match player team goal",
    "player scored goal in the football match",
    "python programming software code",
    "python code programming developer",
    "software programming python developer"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

# %%
X = vectorizer.fit_transform(documents)

print(X.shape)
print(vectorizer.get_feature_names_out()) #DTM matrix M

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=3, random_state=42)

x_lsa = svd.fit_transform(X)

print(x_lsa.shape)

# %%
terms = vectorizer.get_feature_names_out()

for i, component in enumerate(svd.components_):
    print("Component: ",i+1)
    for index in component.argsort()[::-1][:5]:
        print(f"{terms[index]}: {component[index]:.2f}")

# %%
svd.singular_values_ #Sigma

# %%
import pandas as pd

document_topics = pd.DataFrame(
    x_lsa, columns=['Topic 1', 'Topic 2', 'Topic 3']
)

document_topics

# %%
svd.transform(X) #U

# %%
svd.components_ #V

# %%
new = ["camera lens photography photo"]

new = vectorizer.transform(new)

new = svd.transform(new)

new

# %%
documents = [
    # Sports
    "football players scored goals in the match",
    "the striker scored a goal for the football team",
    "the cricket team won the match with excellent batting",
    "players train hard before the football tournament",
    "the coach prepared the team for the final match",
    # Technology
    "machine learning models analyze large amounts of data",
    "artificial intelligence is changing modern technology",
    "deep learning uses neural networks for prediction",
    "software developers build applications using computers",
    "data science and machine learning are used in technology",
    # Politics
    "the government announced a new policy",
    "the political party won the election",
    "the minister discussed the new government policy",
    "election campaigns started before the national election",
    "the government introduced a new law"
]

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %%
vectorizer = CountVectorizer(stop_words="english")

X = vectorizer.fit_transform(documents)

print(X.shape)
print(vectorizer.get_feature_names_out())
# Out:
# (15, 57)
# ['amounts' 'analyze' 'announced' 'applications' 'artificial' 'batting'
#  'build' 'campaigns' 'changing' 'coach' 'computers' 'cricket' 'data'
#  'deep' 'developers' 'discussed' 'election' 'excellent' 'final' 'football'
#  'goal' 'goals' 'government' 'hard' 'intelligence' 'introduced' 'large'
#  'law' 'learning' 'machine' 'match' 'minister' 'models' 'modern'
#  'national' 'networks' 'neural' 'new' 'party' 'players' 'policy'
#  'political' 'prediction' 'prepared' 'science' 'scored' 'software'
#  'started' 'striker' 'team' 'technology' 'tournament' 'train' 'used'
#  'uses' 'using' 'won']

# %%
lda = LatentDirichletAllocation(
    n_components=3,
    random_state=42
)

lda.fit(X)
# Out:
# LatentDirichletAllocation(n_components=3, random_state=42)

# %%
words = vectorizer.get_feature_names_out()

for topic_index, topic in enumerate(lda.components_):

    print(f"\nTopic {topic_index + 1}")

    top_word_indices = topic.argsort()[-5:][::-1]

    for index in top_word_indices:
        print(words[index])
# Out:
# Topic 1
# learning
# football
# machine
# data
# scored
#
# Topic 2
# election
# won
# technology
# match
# team
#
# Topic 3
# government
# new
# policy
# players
# software
